# %%
# Program to generate multiplication table

number = int(input("Enter a number: "))

for i in range(1, 11):
    print(number, "x", i, "=", number * i)
# Out:
# Enter a number:  64
# 64 x 1 = 64
# 64 x 2 = 128
# 64 x 3 = 192
# 64 x 4 = 256
# 64 x 5 = 320
# 64 x 6 = 384
# 64 x 7 = 448
# 64 x 8 = 512
# 64 x 9 = 576
# 64 x 10 = 640
