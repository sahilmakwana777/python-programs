# %%
a = 10
b = 5.5
c = "Hello"

print(a)
print(b)
print(c)

print(type(a))
print(type(b))
print(type(c))

a = float(a)
b = int(b)

print(a)
print(b)

print(type(a))
print(type(b))
# Out:
# 10
# 5.5
# Hello
# <class 'int'>
# <class 'float'>
# <class 'str'>
# 10.0
# 5
# <class 'float'>
# <class 'int'>
